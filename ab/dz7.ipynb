# %%
## Task 1

# %% [markdown]
# На основе выбранных продуктов из первого вебинара, выберите 2 A/B-теста и составьте план эксперимента, чтобы избежать Peeking Problem.
# Распишите, какие метрики и как вы будете анализировать.

# %% [markdown]
# **Гипотеза:** Увеличение количества товарных категорий приведет к увеличению среднего чека пользователей, так как будет больше вариантов для покупки.

# %% [markdown]
# **Контрольная группа:** Пользователям предлагается текущее количество товарных категорий без изменений.
#
# **Тестовая группа:** Пользователям предлагается увеличенное количество товарных категорий.

# %% [markdown]
# **Метрика оценки эффекта:**
#
# **Средний чек:** Показывает среднюю сумму денег, которую клиент тратит на один заказ. Эта метрика является важным показателем при оценке эффективности бизнеса и помогает понимать, насколько успешно работает компания в плане продаж.
# Рассчитать средний чек можно, разделив общую выручку на количество заказов.

# %% [markdown]
# **На каких пользователях тестируем:** На рандомных пользователях.

# %% [markdown]
# Средний чек пользователей в среднем равен 2500 рублей, а стандартная ошибка равна 2000. Мы предполагаем, что в новой версии средний чек пользователей изменится на 5%. Средний трафик 1200 человек в день. Посчитайте сколько дней необходимо держать эксперимент при alpha = 5% и beta = 20%.

# %% [markdown]
# Используя калькулятор https://statulator.com/SampleSize/ss2M.html вводим данные (2500, 2625, 2000)

# %% [markdown]
# Для исследования потребуется размер выборки: 4019 для каждой группы, т.е. общий размер выборки 8038, при условии одинакового размера групп.
# Делим общий размер выборки на средний трафик человек в день:

# %%
8038 / 1200
# Out:
# 6.698333333333333

# %% [markdown]
# Получаем 7 дней тестирования.

# %% [markdown]
# Чтобы избежать Peeking Problem временно блокируем доступ к данным текущего эксперимента всем, кроме технического персонала.

# %% [markdown]
# Для оценки влияния увеличения количества товарных категорий на средний чек пользователей, можно проанализировать следующие метрики:
# * Средний чек: для определения изменения среднего чека можно сравнивать его значение до и после увеличения количества товарных категорий. Если после увеличения количества товарных категорий средний чек увеличится, то можно сделать вывод о положительном влиянии данного фактора на поведение пользователей.
# * Количество заказов: необходимо также учитывать изменение количества заказов до и после увеличения количества товарных категорий. Если количество заказов возрастет, это может означать, что пользователи находят больше интересных для себя товаров.
# * Количество возвратов: важно учитывать изменение количества возвратов товаров, так как это может указывать на то, что пользователи не находят подходящие для себя товары из-за большого количества категорий и трудностей с выбором.

# %% [markdown]
# Для того, чтобы избежать Peeking Problem при проведении эксперимента, необходимо составить план, который включает в себя следующие шаги:
# * Определить цель эксперимента и гипотезы. Определить, какие именно метрики и показатели будут использоваться для оценки результатов эксперимента.
# * Разработать методику проведения эксперимента и выбрать группы тестирования и контроля. Группы должны быть одинаковыми по своим характеристикам, а также выбранные группы не должны пересекаться.
# * Определить размер выборки для каждой группы и провести случайное разбиение пользователей на группы.
# * Начать проведение эксперимента и не проводить анализ результатов до того момента, как будет собрано достаточное количество данных.
# * После того, как собрано достаточное количество данных, провести анализ результатов.
